# %%
import os
p_f = r'Y:\\SZX\\2025_wbi_analysis\\good_WBI\\to_do'
sub_f = os.listdir(p_f)
for s in sub_f:
    files = [f for f in os.listdir(os.path.join(p_f,s))]
    if 'c1_onnx.mp4' not in files:
        print(s)
    if 'output-0516.npz' in files:
        print(s)
# Out:
# 20250225_0g-ov-24d_003
# 20250225_4.5g-ov-24d_002
# 20250225_4.5g-ov-24d_016
# 20250304_4.5g-5.5h-24d_002
